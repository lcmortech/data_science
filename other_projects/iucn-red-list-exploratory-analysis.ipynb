# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/number-of-species-in-each-iucn-red-list-category/Species.csv

# %% [markdown]
# #  **Import**

# %%
import pandas as pd
df = pd.read_csv('/kaggle/input/number-of-species-in-each-iucn-red-list-category/Species.csv')
pd.set_option('max_rows',70)
df
# Out:
#                   Name   EX  EW  Subtotal (EX+EW) CR(PE)  CR(PEW)  \
# 0       ACTINOPTERYGII   79  10                89    122        6
# 1             AMPHIBIA   35   2                37    146        1
# 2             ANTHOZOA    0   0                 0      1        0
# 3            ARACHNIDA    9   0                 9     21        0
# 4           ASTEROIDEA    0   0                 0      0        0
# 5                 AVES  159   5               164     22        0
# 6             BIVALVIA   32   0                32     15        0
# 7         BRANCHIOPODA    0   0                 0      0        0
# 8   CEPHALASPIDOMORPHI    1   0                 1      1        0
# 9          CEPHALOPODA    0   0                 0      0        0
# 10           CHILOPODA    0   0                 0      2        0
# 11      CHONDRICHTHYES    0   0                 0      3        0
# 12          CLITELLATA    2   0                 2      4        0
# ...

# %% [markdown]
# # **Examining the first and last five rows in the dataset**

# %%
# Examining the FIRST five rows

df.head(10)
# Out:
#                  Name   EX  EW  Subtotal (EX+EW) CR(PE)  CR(PEW)  \
# 0      ACTINOPTERYGII   79  10                89    122        6
# 1            AMPHIBIA   35   2                37    146        1
# 2            ANTHOZOA    0   0                 0      1        0
# 3           ARACHNIDA    9   0                 9     21        0
# 4          ASTEROIDEA    0   0                 0      0        0
# 5                AVES  159   5               164     22        0
# 6            BIVALVIA   32   0                32     15        0
# 7        BRANCHIOPODA    0   0                 0      0        0
# 8  CEPHALASPIDOMORPHI    1   0                 1      1        0
# 9         CEPHALOPODA    0   0                 0      0        0
#
#   Subtotal (EX+EW+ CR(PE)+CR(PEW))   CR     EN     VU  \
# 0                              217  626  1,000  1,241
# 1                              184  663  1,060    721
# 2                                1    6     26    202
# ...

# %%
#Examining the LAST five rows

df.tail(10)
# Out:
#                Name   EX  EW  Subtotal (EX+EW) CR(PE)  CR(PEW)  \
# 58   LYCOPODIOPSIDA    0   0                 0      2        0
# 59    MAGNOLIOPSIDA  102  31               133    417       29
# 60  MARCHANTIOPSIDA    0   0                 0      0        0
# 61        PINOPSIDA    0   0                 0      1        0
# 62   POLYPODIOPSIDA    2   1                 3      8        0
# 63  POLYTRICHOPSIDA    0   0                 0      0        0
# 64     SPHAGNOPSIDA    0   0                 0      0        0
# 65     TAKAKIOPSIDA    0   0                 0      0        0
# 66      ULVOPHYCEAE    0   0                 0      0        0
# 67            Total  902  80               982  1,160       55
#
#    Subtotal (EX+EW+ CR(PE)+CR(PEW))     CR      EN      VU  \
# 58                                2     14      12      16
# 59                              579  3,904   7,352   7,294
# 60                                0      2       3       2
# ...

# %% [markdown]
# # **General Stats**

# %%
df.shape #NO parenthesis
# 68 rows, 16 columns
# Out:
# (68, 16)

# %%
df.describe()
# Out:
#                EX         EW  Subtotal (EX+EW)    CR(PEW)       LR/cd
# count   68.000000  68.000000         68.000000  68.000000   68.000000
# mean    26.529412   2.352941         28.882353   1.617647    5.000000
# std    115.498203  10.499132        125.477539   7.619749   26.716868
# min      0.000000   0.000000          0.000000   0.000000    0.000000
# 25%      0.000000   0.000000          0.000000   0.000000    0.000000
# 50%      0.000000   0.000000          0.000000   0.000000    0.000000
# 75%      2.000000   0.000000          2.250000   0.000000    0.000000
# max    902.000000  80.000000        982.000000  55.000000  170.000000

# %% [markdown]
# # **Cleaning The Data**

# %%
# Checking for null values

df.isna().sum()

# None present
# Out:
# Name                                0
# EX                                  0
# EW                                  0
# Subtotal (EX+EW)                    0
# CR(PE)                              0
# CR(PEW)                             0
# Subtotal (EX+EW+ CR(PE)+CR(PEW))    0
# CR                                  0
# EN                                  0
# VU                                  0
# Subtotal (threatened spp.)          0
# LR/cd                               0
# NT or LR/nt                         0
# LC or LR/lc                         0
# DD                                  0
# Total                               0
# dtype: int64

# %%
df = df.drop_duplicates()

# %% [markdown]
# # **Subsetting Data**

# %%
df.columns
# Out:
# Index(['Name', 'EX', 'EW', 'Subtotal (EX+EW)', 'CR(PE)', 'CR(PEW)',
#        'Subtotal (EX+EW+ CR(PE)+CR(PEW))', 'CR', 'EN', 'VU',
#        'Subtotal (threatened spp.)', 'LR/cd', 'NT or LR/nt', 'LC or LR/lc',
#        'DD', 'Total'],
#       dtype='object')

# %%
df['Name']
# Out:
# 0         ACTINOPTERYGII
# 1               AMPHIBIA
# 2               ANTHOZOA
# 3              ARACHNIDA
# 4             ASTEROIDEA
# 5                   AVES
# 6               BIVALVIA
# 7           BRANCHIOPODA
# 8     CEPHALASPIDOMORPHI
# 9            CEPHALOPODA
# 10             CHILOPODA
# 11        CHONDRICHTHYES
# 12            CLITELLATA
# 13            COLLEMBOLA
# 14             DIPLOPODA
# 15            ECHINOIDEA
# 16                ENOPLA
# 17            GASTROPODA
# 18           HEXANAUPLIA
# 19         HOLOTHUROIDEA
# 20              HYDROZOA
# 21               INSECTA
# 22          MALACOSTRACA
# 23              MAMMALIA
# 24           MAXILLOPODA
# 25           MEROSTOMATA
# 26        MONOPLACOPHORA
# 27                MYXINI
# 28             OSTRACODA
# 29            POLYCHAETA
# 30        POLYPLACOPHORA
# 31              REPTILIA
# 32         SARCOPTERYGII
# 33           TURBELLARIA
# 34        UDEONYCHOPHORA
# 35          PHAEOPHYCEAE
# 36        AGARICOMYCETES
# ...

# %%
df.loc[:,'Name']
# Out:
# 0         ACTINOPTERYGII
# 1               AMPHIBIA
# 2               ANTHOZOA
# 3              ARACHNIDA
# 4             ASTEROIDEA
# 5                   AVES
# 6               BIVALVIA
# 7           BRANCHIOPODA
# 8     CEPHALASPIDOMORPHI
# 9            CEPHALOPODA
# 10             CHILOPODA
# 11        CHONDRICHTHYES
# 12            CLITELLATA
# 13            COLLEMBOLA
# 14             DIPLOPODA
# 15            ECHINOIDEA
# 16                ENOPLA
# 17            GASTROPODA
# 18           HEXANAUPLIA
# 19         HOLOTHUROIDEA
# 20              HYDROZOA
# 21               INSECTA
# 22          MALACOSTRACA
# 23              MAMMALIA
# 24           MAXILLOPODA
# 25           MEROSTOMATA
# 26        MONOPLACOPHORA
# 27                MYXINI
# 28             OSTRACODA
# 29            POLYCHAETA
# 30        POLYPLACOPHORA
# 31              REPTILIA
# 32         SARCOPTERYGII
# 33           TURBELLARIA
# 34        UDEONYCHOPHORA
# 35          PHAEOPHYCEAE
# 36        AGARICOMYCETES
# ...

# %%
df[['Name','EX']]
# Out:
#                   Name   EX
# 0       ACTINOPTERYGII   79
# 1             AMPHIBIA   35
# 2             ANTHOZOA    0
# 3            ARACHNIDA    9
# 4           ASTEROIDEA    0
# 5                 AVES  159
# 6             BIVALVIA   32
# 7         BRANCHIOPODA    0
# 8   CEPHALASPIDOMORPHI    1
# 9          CEPHALOPODA    0
# 10           CHILOPODA    0
# 11      CHONDRICHTHYES    0
# 12          CLITELLATA    2
# 13          COLLEMBOLA    0
# 14           DIPLOPODA    3
# 15          ECHINOIDEA    0
# 16              ENOPLA    1
# 17          GASTROPODA  267
# 18         HEXANAUPLIA    1
# 19       HOLOTHUROIDEA    0
# 20            HYDROZOA    0
# 21             INSECTA   63
# 22        MALACOSTRACA    7
# 23            MAMMALIA   85
# 24         MAXILLOPODA    1
# 25         MEROSTOMATA    0
# 26      MONOPLACOPHORA    0
# 27              MYXINI    0
# 28           OSTRACODA    2
# 29          POLYCHAETA    0
# 30      POLYPLACOPHORA    0
# 31            REPTILIA   32
# ...

# %%
new_df = df[['Name','LC or LR/lc' ,'VU', 'EN', 'CR', 'EX']]
new_df
# Out:
#                   Name LC or LR/lc      VU      EN     CR   EX
# 0       ACTINOPTERYGII      13,064   1,241   1,000    626   79
# 1             AMPHIBIA       3,129     721   1,060    663   35
# 2             ANTHOZOA         293     202      26      6    0
# 3            ARACHNIDA          91      62      88     68    9
# 4           ASTEROIDEA           0       0       0      1    0
# 5                 AVES       8,460     798     460    223  159
# 6             BIVALVIA         339      60      68     83   32
# 7         BRANCHIOPODA           1      22      13      8    0
# 8   CEPHALASPIDOMORPHI          22       2       4      2    1
# 9          CEPHALOPODA         324       2       2      1    0
# 10           CHILOPODA           1       1       5      3    0
# 11      CHONDRICHTHYES         534     180     124     89    0
# 12          CLITELLATA          74       8      13      6    2
# 13          COLLEMBOLA           0       2       0      2    0
# ...

# %%
new_df['VU'].value_counts()
# Out:
# 0         13
# 1         11
# 2          9
# 4          2
# 9          2
# 3          2
# 15         2
# 74         1
# 113        1
# 33         1
# 1,241      1
# 20         1
# 6          1
# 1,061      1
# 16         1
# 7,294      1
# 80         1
# 84         1
# 561        1
# 309        1
# 47         1
# 555        1
# 721        1
# 850        1
# 24         1
# 980        1
# 8          1
# 180        1
# 22         1
# 60         1
# 798        1
# 62         1
# 202        1
# 15,492     1
# Name: VU, dtype: int64

# %% [markdown]
# ## **Different Visualizations**

# %%
# import matplotlib

import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
# Histogram

new_df['EX'].plot(kind='hist', bins=50, title='Distribution of Extinct Numbers',figsize=(10,2))
# Out:
# <AxesSubplot:title={'center':'Distribution of Extinct Numbers'}, ylabel='Frequency'>

# %%
# Scatter plot
df.plot(kind='scatter', x='LC or LR/lc',y='VU',title='Least Concern vs Vulnerable Species')
# Out:
# <AxesSubplot:title={'center':'Least Concern vs Vulnerable Species'}, xlabel='LC or LR/lc', ylabel='VU'>

# %%
ax = new_df['VU'].value_counts()\
.head(10)\
.plot(kind='bar',title='Vulnerable Populations')

# %%
new_df['EX'].plot(kind='kde', title='Extinct Numbers')
# Out:
# <AxesSubplot:title={'center':'Extinct Numbers'}, ylabel='Density'>

# %%
new_df['VU'].value_counts().plot(kind='hist', bins=20, title='Distribution of Vulnerable Populations')
# Out:
# <AxesSubplot:title={'center':'Distribution of Vulnerable Populations'}, ylabel='Frequency'>
